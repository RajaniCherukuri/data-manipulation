# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

data_ba = pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
data_bo = pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
data_ny = pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
data_ph = pd.read_csv("dataset/philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
data_ba.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ba.info
# Out:
# <bound method DataFrame.info of     Commodity Name  City Name  Type             Package      Variety  \
# 0         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 1         PUMPKINS  BALTIMORE   NaN        24 inch bins          NaN
# 2         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# ..             ...        ...   ...                 ...          ...
# 148       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 149       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 150       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 151       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
# 152       PUMPKINS  BALTIMORE   NaN  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0           NaN    NaN  04/29/2017        270       280.0  ...     NaN
# 1           NaN    NaN  05/06/2017        270       280.0  ...     NaN
# 2           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 3           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 4           NaN    NaN  11/05/2016         90       100.0  ...     NaN
# ..          ...    ...         ...        ...         ...  ...     ...
# 148         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 149         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 150  ROUND TYPE    NaN  09/24/2016         15        15.0  ...     NaN
# 151  ROUND TYPE    NaN  10/01/2016         15        15.0  ...     NaN
# 152  ROUND TYPE    NaN  10/08/2016         15        15.0  ...     NaN
#
#      Environment Unit of Sale  Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# ..           ...          ...      ...       ...        ...      ...  ...
# 148          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 149          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 150          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 151          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 152          NaN          NaN      NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         E         NaN
# 1         E         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 148       N         NaN
# 149       N         NaN
# 150       N         NaN
# 151       N         NaN
# 152       N         NaN
#
# [153 rows x 25 columns]>

# %%
for col in data_ba.columns:
    pct_missing = np.mean(data_ba[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
total_cells = np.product(data_ba.shape)

missing_cells = pd.isnull(data_ba).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 51.0 % Missing cells from the data

# %%
data_ba.duplicated().sum()
# Out:
# 0

# %%
#data.drop_duplicates()

# %%
data_ba["Type"] = data_ba["Type"].fillna("Conventional")
data_ba.head()
# Out:
#   Commodity Name  City Name          Type       Package      Variety  \
# 0       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 1       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 2       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0         NaN    NaN  04/29/2017        270       280.0  ...    NaN
# 1         NaN    NaN  05/06/2017        270       280.0  ...    NaN
# 2         NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 3         NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 4         NaN    NaN  11/05/2016         90       100.0  ...    NaN
#
#    Environment Unit of Sale  Quality Condition Appearance  Storage Crop  \
# 0          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 1          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 2          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 3          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 4          NaN          NaN      NaN       NaN        NaN      NaN  NaN
#
#    Repack  Trans Mode
# 0       E         NaN
# 1       E         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ba = data_ba.drop(["Grade","Sub Variety","Mostly High","Mostly Low","Origin District","Environment","Appearance","Condition","Storage","Crop","Quality","Trans Mode"], axis=1)

# %%
data_ba.shape
# Out:
# (153, 13)

# %%
data_ba.head()
# Out:
#   Commodity Name  City Name          Type       Package      Variety  \
# 0       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 1       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 2       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
#
#          Date  Low Price  High Price    Origin Item Size Color Unit of Sale  \
# 0  04/29/2017        270       280.0       NaN       lge   NaN          NaN
# 1  05/06/2017        270       280.0       NaN       lge   NaN          NaN
# 2  09/24/2016        160       160.0  DELAWARE       med   NaN          NaN
# 3  09/24/2016        160       160.0  VIRGINIA       med   NaN          NaN
# 4  11/05/2016         90       100.0  MARYLAND       lge   NaN          NaN
#
#   Repack
# 0      E
# 1      E
# 2      N
# 3      N
# 4      N

# %%
#data_ba = data_ba['Commodity Name','City Name','Variety','Origin'].str.lower()

# %%
data_bo.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...   Color  Environment  \
# 0    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 1    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 2    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 3    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 4    NaN  09/24/2016        160         180  ...  ORANGE          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_bo.duplicated().sum()
# Out:
# 0

# %%
data_bo["Type"] = data_bo["Type"].fillna("Conventional")
data_bo.head()
# Out:
#   Commodity Name City Name          Type       Package      Variety  \
# 0       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 1       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0         NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 1         NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 2         NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 3         NaN    NaN  09/24/2016        160         200  ...  ORANGE
# 4         NaN    NaN  09/24/2016        160         180  ...  ORANGE
#
#    Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#    Repack  Trans Mode
# 0       N         NaN
# 1       N         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 25 columns]

# %%
data_bo = data_bo.drop(["Grade","Sub Variety","Mostly High","Mostly Low","Origin District","Environment","Appearance","Condition","Storage","Crop","Quality","Trans Mode"], axis=1)

# %%
data_bo.shape
# Out:
# (352, 13)

# %%
data_bo.head()
# Out:
#   Commodity Name City Name          Type       Package      Variety  \
# 0       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 1       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS    BOSTON  Conventional  36 inch bins  HOWDEN TYPE
#
#          Date  Low Price  High Price  Origin Item Size   Color Unit of Sale  \
# 0  09/24/2016        160         200  CANADA     exjbo  ORANGE          NaN
# 1  09/24/2016        160         200  CANADA       jbo  ORANGE          NaN
# 2  09/24/2016        160         200  CANADA      xlge  ORANGE          NaN
# 3  09/24/2016        160         200  CANADA      xlge  ORANGE          NaN
# 4  09/24/2016        160         180  CANADA       lge  ORANGE          NaN
#
#   Repack
# 0      N
# 1      N
# 2      N
# 3      N
# 4      N

# %%
data_ny.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ny["Type"] = data_bo["Type"].fillna("Conventional")
data_ny.head()
# Out:
#   Commodity Name City Name          Type       Package      Variety  \
# 0       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 1       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0         NaN    NaN  09/24/2016        150         170  ...    NaN
# 1         NaN    NaN  09/24/2016        150         170  ...    NaN
# 2         NaN    NaN  09/24/2016        130         150  ...    NaN
# 3         NaN    NaN  09/24/2016        130         150  ...    NaN
# 4         NaN    NaN  09/24/2016        120         140  ...    NaN
#
#    Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#    Repack  Trans Mode
# 0       N         NaN
# 1       N         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ny = data_ny.drop(["Grade","Sub Variety","Mostly High","Mostly Low","Origin District","Environment","Appearance","Condition","Storage","Crop","Quality","Trans Mode"], axis=1)

# %%
data_ny.shape
# Out:
# (112, 13)

# %%
data_ny.head()
# Out:
#   Commodity Name City Name          Type       Package      Variety  \
# 0       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 1       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS  NEW YORK  Conventional  36 inch bins  HOWDEN TYPE
#
#          Date  Low Price  High Price      Origin Item Size Color Unit of Sale  \
# 0  09/24/2016        150         170    MICHIGAN      xlge   NaN          NaN
# 1  09/24/2016        150         170    MICHIGAN       lge   NaN          NaN
# 2  09/24/2016        130         150  NEW JERSEY      xlge   NaN          NaN
# 3  09/24/2016        130         150  NEW JERSEY       lge   NaN          NaN
# 4  09/24/2016        120         140    NEW YORK   med-lge   NaN          NaN
#
#   Repack
# 0      N
# 1      N
# 2      N
# 3      N
# 4      N

# %%
data_ph.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN  NaN       N
# 1          NaN      NaN       NaN         NaN      NaN  NaN       N
# 2          NaN      NaN       NaN         NaN      NaN  NaN       N
# 3          NaN      NaN       NaN         NaN      NaN  NaN       N
# 4          NaN      NaN       NaN         NaN      NaN  NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 25 columns]

# %%
data_ph["Type"] = data_bo["Type"].fillna("Conventional")
data_ph.head()
# Out:
#   Commodity Name     City Name          Type       Package      Variety  \
# 0       PUMPKINS  PHILADELPHIA  Conventional  24 inch bins  HOWDEN TYPE
# 1       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0         NaN    NaN  09/16/2017        140         150  ...    NaN
# 1         NaN    NaN  09/24/2016        150         150  ...    NaN
# 2         NaN    NaN  09/24/2016        150         150  ...    NaN
# 3         NaN    NaN  09/24/2016        150         160  ...    NaN
# 4         NaN    NaN  10/01/2016        140         140  ...    NaN
#
#    Environment Unit of Sale  Quality Condition  Appearance  Storage Crop  \
# 0          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 1          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 2          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 3          NaN          NaN      NaN       NaN         NaN      NaN  NaN
# 4          NaN          NaN      NaN       NaN         NaN      NaN  NaN
#
#    Repack  Trans Mode
# 0       N         NaN
# 1       N         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ph = data_ph.drop(["Grade","Sub Variety","Mostly High","Mostly Low","Origin District","Environment","Appearance","Condition","Storage","Crop","Quality","Trans Mode"], axis=1)

# %%
data_ph.shape
# Out:
# (57, 13)

# %%
data_ph.head()
# Out:
#   Commodity Name     City Name          Type       Package      Variety  \
# 0       PUMPKINS  PHILADELPHIA  Conventional  24 inch bins  HOWDEN TYPE
# 1       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 2       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 3       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
# 4       PUMPKINS  PHILADELPHIA  Conventional  36 inch bins  HOWDEN TYPE
#
#          Date  Low Price  High Price        Origin Item Size  Color  \
# 0  09/16/2017        140         150  PENNSYLVANIA       lge    NaN
# 1  09/24/2016        150         150      NEW YORK   med-lge    NaN
# 2  09/24/2016        150         150      NEW YORK       med    NaN
# 3  09/24/2016        150         160  PENNSYLVANIA       lge    NaN
# 4  10/01/2016        140         140    NEW JERSEY   med-lge    NaN
#
#   Unit of Sale Repack
# 0          NaN      N
# 1          NaN      N
# 2          NaN      N
# 3          NaN      N
# 4          NaN      N

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
data_ne_region = pd.concat([data_ba,data_bo,data_ny,data_ph])
data_ne_region
# Out:
#    Commodity Name     City Name          Type             Package  \
# 0        PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 1        PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 2        PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 3        PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 4        PUMPKINS     BALTIMORE  Conventional        24 inch bins
# ..            ...           ...           ...                 ...
# 52       PUMPKINS  PHILADELPHIA  Conventional  1/2 bushel cartons
# 53       PUMPKINS  PHILADELPHIA  Conventional  1/2 bushel cartons
# 54       PUMPKINS  PHILADELPHIA  Conventional  1/2 bushel cartons
# 55       PUMPKINS  PHILADELPHIA  Conventional  1/2 bushel cartons
# 56       PUMPKINS  PHILADELPHIA  Conventional  1/2 bushel cartons
#
#         Variety        Date  Low Price  High Price    Origin Item Size Color  \
# 0           NaN  04/29/2017        270       280.0       NaN       lge   NaN
# 1           NaN  05/06/2017        270       280.0       NaN       lge   NaN
# 2   HOWDEN TYPE  09/24/2016        160       160.0  DELAWARE       med   NaN
# 3   HOWDEN TYPE  09/24/2016        160       160.0  VIRGINIA       med   NaN
# 4   HOWDEN TYPE  11/05/2016         90       100.0  MARYLAND       lge   NaN
# ..          ...         ...        ...         ...       ...       ...   ...
# 52    MINIATURE  11/05/2016         16        18.0      OHIO       NaN   NaN
# 53    MINIATURE  08/26/2017         18        20.0  MICHIGAN       NaN   NaN
# 54    MINIATURE  09/16/2017         16        16.0      OHIO       NaN   NaN
# 55    MINIATURE  09/23/2017         15        16.0      OHIO       NaN   NaN
# 56    MINIATURE  09/30/2017         15        18.0      OHIO       NaN   NaN
#
#    Unit of Sale Repack
# 0           NaN      E
# 1           NaN      E
# 2           NaN      N
# 3           NaN      N
# 4           NaN      N
# ..          ...    ...
# 52   SHELLACKED      N
# 53   SHELLACKED      N
# 54   SHELLACKED      N
# 55   SHELLACKED      N
# 56   SHELLACKED      N
#
# [674 rows x 13 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
data_ne_region.groupby(['Unit of Sale']).mean()
# Out:
# C:\Users\chakr\AppData\Local\Temp\ipykernel_13852\1438600968.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_ne_region.groupby(['Unit of Sale']).mean()
#                Low Price  High Price
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.

data_ne_region.groupby(['Variety']).mean()
# Out:
# C:\Users\chakr\AppData\Local\Temp\ipykernel_13852\2022190490.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_ne_region.groupby(['Variety']).mean()
#                            Low Price  High Price
# Variety
# BIG MACK TYPE             129.454545  147.272727
# BLUE TYPE                 260.000000  285.000000
# CINDERELLA                206.051282  220.974359
# FAIRYTALE                 198.783784  214.108108
# HOWDEN TYPE               152.834821  177.098214
# HOWDEN WHITE TYPE         170.000000  180.000000
# KNUCKLE HEAD              238.888889  260.555556
# MINIATURE                  16.391753   17.886598
# MIXED HEIRLOOM VARIETIES  210.000000  230.000000
# PIE TYPE                  133.404040  148.118687

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
